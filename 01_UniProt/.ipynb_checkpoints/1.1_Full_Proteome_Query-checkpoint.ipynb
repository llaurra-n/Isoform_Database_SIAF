# %% [markdown]
# <div style="background-color: #ffcccc; padding: 10px; border: 1px solid red;">
#     <h3><strong>Remark</strong></h3>
#     The data queried in this notebook is not used for the isoforms database (data was directly downloaded from UniProtKB, see notebook 1.2)
# </div>

# %% [markdown]
# # Get full human proteome and ioforms from UniProt
# In this Notebook we will use SPARQL to query UniProt RDF data and get a list of Accession IDs and UniProt Rest API to fetch the isoform data since it is more robust for large lists of proteins than SPARQL.

# %% [markdown]
# # Setup
# ## Import Packages
# SPARQLWrapper is a simple Python wrapper around a SPARQL service to remotelly execute your queries. It helps increating the queryinvokationand,possibly, convertthe result into a more manageable format.

# %%
import sys
import os
import session_info

# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import time
import requests

# %%
# Display session information
session_info.show()

# %% [markdown]
# ## Set working directory

# %%
cwd = os.getcwd()
if not cwd.endswith("Isoform_Database/Jupyter_environment/01_UniProt"):
    print("WARNING: The working directory is not set to the '01_UniProt'!")
    print("Current working directory:", cwd)
else:
    print(f"Working directory is correctly set to the '01_Uniprot' folder (\"{cwd}\").")

# %%
# %%bash -s "data"
# mkdir -p "$1"

# %%
# Data directory for fetched data
data_dir = "data"
raw_data_dir = "data/raw_data"

# %% [markdown]
# # Querying UniProt
# ## Get canonical forms of all human proteins in UniProt
# The next cell is skipped by default. If you run this notebook for the first time change the next cell from raw to code in order to run it.

# %% [raw]
# # 1. Initialize the endpoint
# sparql = SPARQLWrapper("https://sparql.uniprot.org/sparql")
# sparql.setReturnFormat(JSON)
# sparql.addCustomHttpHeader("User-Agent", "Isoform_Database/1.0 (lnieba@student.ethz.ch)")
#
# # 2. Set Pagination Parameters
# limit = 1500
# offset = 0
# all_proteins = []
# continue_query = True
#
# print("Starting data retrieval")
#
# # 3. Pagination Loop
# while continue_query:
#     query = f"""
#     PREFIX up: <http://purl.uniprot.org/core/>
#     PREFIX taxon: <http://purl.uniprot.org/taxonomy/>
#     PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
#     SELECT ?accession ?name ?sequence
#            (GROUP_CONCAT(DISTINCT ?evCode; SEPARATOR="; ") AS ?evidenceCodes)
#     WHERE {{
#       ?protein a up:Protein ;
#                up:organism taxon:9606 ;
#                up:reviewed true ;        #only reviewed Swiss-Prot
#                up:mnemonic ?name ;
#                up:sequence/rdf:value ?sequence .
#
#       BIND(SUBSTR(STR(?protein), 33) AS ?accession)
#     }}
#     GROUP BY ?accession ?name ?sequence
#     LIMIT {limit}
#     OFFSET {offset}
#     """
#
#     sparql.setQuery(query)
#
#     try:
#         response = sparql.query().convert()
#         bindings = response["results"]["bindings"]
#
#         if not bindings:
#             print("\n All data retrieved successfully.")
#             continue_query = False
#             break
#
#         # Parse current batch
#         for row in bindings:
#             all_proteins.append({
#                 "ID": row["accession"]["value"],
#                 "Name": row["name"]["value"],
#                 "Sequence": row["sequence"]["value"],
#             })
#
#         print(f" Fetched {len(all_proteins)} proteins (Last Offset: {offset})")
#
#         # Increment offset
#         offset += limit
#         # Brief pause to avoid rate-limiting
#         time.sleep(0.3)
#
#     except Exception as e:
#         print(f" Error at offset {offset}: {e}")
#         # you might want to retry here instead of breaking
#         continue_query = False
#
#
# # 4. Final Data Processing
# full_proteome = pd.DataFrame(all_proteins)
# print(f"\nTotal proteins retrieved: {len(full_proteome)}")
# # save to CSV so you don't have to run it again
# full_proteome.to_csv("data/human_proteome_list.csv", index=False)

# %% [raw]
# ## Second try with isoform specific ids
# # 1. Initialize the endpoint
# sparql = SPARQLWrapper("https://sparql.uniprot.org/sparql")
# sparql.setReturnFormat(JSON)
# sparql.addCustomHttpHeader("User-Agent", "Isoform_Database/1.0 (lnieba@student.ethz.ch)")
#
# # 2. Set Pagination Parameters
# limit = 1500
# offset = 0
# all_proteins = []
# continue_query = True
#
# print("Starting data retrieval")
#
# # 3. Pagination Loop
# while continue_query:
#     query = f"""
#     PREFIX up: <http://purl.uniprot.org/core/>
#     PREFIX taxon: <http://purl.uniprot.org/taxonomy/>
#     PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
#     SELECT ?full_id ?name ?sequence
#            (GROUP_CONCAT(DISTINCT ?evCode; SEPARATOR="; ") AS ?evidenceCodes)
#     WHERE {{
#       ?protein a up:Protein ;
#                up:organism taxon:9606 ;
#                up:reviewed true ;        #only reviewed Swiss-Prot
#                up:mnemonic ?name .
#
#       # This part finds BOTH the canonical and the isoforms
#       ?protein up:component ?seq_obj .
#       ?seq_obj rdf:value ?sequence .
#
#       # Filter out non-sequence components if necessary
#       FILTER(CONTAINS(STR(?seq_obj), "uniprot.org/uniprot/"))
#
#       BIND(SUBSTR(STR(?seq_obj), 33) AS ?full_id)
#     }}
#     GROUP BY ?full_id ?name ?sequence
#     LIMIT {limit}
#     OFFSET {offset}
#     """
#
#     sparql.setQuery(query)
#
#     try:
#         response = sparql.query().convert()
#         bindings = response["results"]["bindings"]
#
#         if not bindings:
#             print("\n All data retrieved successfully.")
#             continue_query = False
#             break
#
#         # Parse current batch
#         for row in bindings:
#             all_proteins.append({
#                 "ID": row["full_id"]["value"],
#                 "Name": row["name"]["value"],
#                 "Sequence": row["sequence"]["value"],
#             })
#
#         print(f" Fetched {len(all_proteins)} proteins (Last Offset: {offset})")
#
#         # Increment offset
#         offset += limit
#         # Brief pause to avoid rate-limiting
#         time.sleep(0.3)
#
#     except Exception as e:
#         print(f" Error at offset {offset}: {e}")
#         # you might want to retry here instead of breaking
#         continue_query = False
#
#
# # 4. Final Data Processing
# full_proteome_unique = pd.DataFrame(all_proteins)
# print(f"\nTotal proteins retrieved: {len(full_proteome)}")
# # save to CSV so you don't have to run it again
# full_proteome_unique.to_csv("data/human_proteome_list_unique.csv", index=False)

# %%
full_proteome = pd.read_csv("data/human_proteome_list.csv")

# %%
#check how many proteins were fetched by query
print(f"Found {len(full_proteome)} proteins in UniProt.")

#check how many unique protein ids were found
unique = len(full_proteome["ID"].unique())
print(f"There are {unique} unique IDs.")

# %%
#take a quick look at the output table
full_proteome.head(10)

# %% [markdown]
# ## Get protein isoforms
# The following function fetches isoform sequences for a list of UniProt Accessions. For this task we are using the UniProt REST API because since this task is to computationally heavy for the UniProt SPARQL endpoint.

# %%
#list of protein ids
accessions_list = full_proteome["ID"].unique().tolist()

# %%
#take a quick look at the accessions list
accessions_list[0:10]

# %% [raw]
# def get_full_sequence_from_fasta(isoform_id):
#     """
#     Fetches the full concatenated amino acid string for a specific ID.
#     """
#     url = f"https://rest.uniprot.org/uniprotkb/{isoform_id}.fasta"
#     try:
#         response = requests.get(url)
#         if response.status_code == 200:
#             # Skip the header line (starts with '>') and join the rest
#             lines = response.text.splitlines()
#             return "".join(lines[1:])
#     except Exception as e:
#         print(f"Error fetching sequence for {isoform_id}: {e}")
#     return None
#
# def get_isoform_sequences(accessions):
#     base_url = "https://rest.uniprot.org/uniprotkb/search"
#     all_data = []
#
#     # Batch size of 25 for the initial metadata search
#     batch_size = 25
#     for i in range(0, len(accessions), batch_size):
#         batch = accessions[i:i + batch_size]
#         query_string = " OR ".join([f"accession:{acc}" for acc in batch])
#
#         params = {
#             "query": f"({query_string})",
#             "fields": "accession,sequence,cc_alternative_products",
#             "format": "json"
#         }
#
#         response = requests.get(base_url, params=params)
#         if response.status_code != 200:
#             print(f"Error {response.status_code} on batch {i}")
#             continue
#
#         results = response.json().get('results', [])
#
#         for entry in results:
#             parent_acc = entry['primaryAccession']
#
#             # 1. Store Canonical Sequence (already provided in the entry)
#             canonical_seq = entry['sequence']['value']
#             all_data.append({
#                 "ID": parent_acc,
#                 "isoform_id": f"{parent_acc}-1",
#                 "sequence": canonical_seq
#             })
#
#             # 2. Identify and Fetch Alternative Isoforms
#             comments = entry.get('comments', [])
#             for comment in comments:
#                 if "ALTERNATIVE" in comment.get('commentType', ''):
#                     isoforms = comment.get('isoforms', [])
#                     for iso in isoforms:
#                         ids = iso.get('isoformIds', [])
#
#                         # We only want IDs that aren't the canonical -1
#                         for iso_id in ids:
#                             if iso_id != f"{parent_acc}-1":
#                                 print(f"  --> Fetching full sequence for {iso_id}")
#                                 full_seq = get_full_sequence_from_fasta(iso_id)
#
#                                 if full_seq:
#                                     all_data.append({
#                                         "ID": parent_acc,
#                                         "isoform_id": iso_id,
#                                         "sequence": full_seq
#                                     })
#                                 time.sleep(0.2)
#
#         print(f"Processed batch {i//batch_size + 1}")
#         time.sleep(0.5) # Courteous delay for main batches
#
#     return pd.DataFrame(all_data)
#
# # --- Execution ---
# # List of accessions known to have isoforms (from your previous SPARQL step)
# full_proteome_isoforms = get_isoform_sequences(accessions_list)
# full_proteome_isoforms.to_csv("data/human_proteome_isoforms_list.csv", index=False)

# %%
#read in query output table
full_proteome_isoforms = pd.read_csv("data/human_proteome_isoforms_list.csv")

# %%
#check how many proteins were fetched by query
print(f"Found {len(full_proteome_isoforms)} isoforms in UniProt.")

#check how many unique protein ids were found
len(full_proteome_isoforms["isoform_id"].unique())

# %%
#take a quick look at the output table
full_proteome_isoforms.head(10)

# %% [markdown]
# ## Check if IDs and sequences match between the two dataframes

# %%
#check if all the canonical protein IDs are in the isoform df
full_proteome["ID"].isin(full_proteome_isoforms["ID"]).all()

# %%
#check if all the canonical protein sequences are in the isoform df
full_proteome["Sequence"].isin(full_proteome_isoforms["sequence"]).all()

# %%
#check how many are a match
mask = full_proteome["Sequence"].isin(full_proteome_isoforms["sequence"])

print(f"{len(full_proteome[mask])} canonical records have a sequence found in the isoform df.")
print(f"{len(full_proteome[~mask])} canonical records have no matching sequence in the isoform df.")

# %%
#have a look at the ones that don't match
no_match_seq = full_proteome[~mask].reset_index(drop=True)
no_match_seq

# %%
#other way around
#check how many of the isoform protein IDs are in the canonical df
full_proteome_isoforms["ID"].isin(full_proteome["ID"]).sum()

# %%
#check how many of the isoform protein sequences are in the canonical df
full_proteome_isoforms["sequence"].isin(full_proteome["Sequence"]).sum()

# %%
len(full_proteome["Sequence"].unique())

# %%
len(full_proteome_isoforms["sequence"].unique())
